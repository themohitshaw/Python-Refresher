# %%
a = 5

# %%
b = 3

# %%
a+b
# Out:
# 8

# %%
name = "Harry"

# %%
print("Hello World") #This will print hello world on the screen
# Out:
# Hello World

# %%
#This is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(str)
# Out:
# type

# %%
a = "4567"
b = "7890"
print(a+b)
# Out:
# 45677890

# %%
int(a)+int(b)
# Out:
# 12457
