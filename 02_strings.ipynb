# %%
name = "Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name
# Out:
# 'Harry'

# %%
name.lower()
# Out:
# 'harry'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("RY")
# Out:
# False

# %%
name.endswith("jarry")
# Out:
# False

# %%
name.count('a')
# Out:
# 1

# %%
name.count('r')
# Out:
# 2

# %%
name.title()
# Out:
# 'Harry'

# %%
string = "CodesWithHarry"
print(len(string))
# Out:
# 14

# %%
string[0:5]
# Out:
# 'Codes'

# %%
string[1:-1]
# Out:
# 'odesWithHarr'
