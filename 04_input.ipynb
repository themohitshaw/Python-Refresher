# %%
a = input("Enter a number")  #By default it takes the string value from the user
# Out:
# Enter a number 34

# %%
a
# Out:
# '34'

# %%
b = input("Enter a number")
# Out:
# Enter a number 23

# %%
a+b
# Out:
# '3423'

# %%
int(a) + int()
